# %%
import os
folder_path = r"C:\Users\koush\Desktop\GenAi project folder\CSV"
all_files = os.listdir(folder_path)
non_genAi_files=[f for f in all_files if f.startswith("non")]
genAi_files=[f for f in all_files if f.startswith("genai")]
print("genAi files", len(genAi_files))
print("non genAi files", len(non_genAi_files))
# Out:
# genAi files 23
# non genAi files 25

# %%
rows = []

# %%
for file in genAi_files:
    f = file.replace(".csv","")
    f = f.split("_")

    label = "genai"
    app = f[1]
    mode = f[2]
    run_id = f[3]
    category= None

    rows.append({
        "file": file,
        "label": label,
        "category": category,
        "app": app,
        "mode": mode,
        "run_id": run_id
    })

# %%
for file in non_genAi_files:
    f = file.replace(".csv","")
    f = f.split("_")

    if f[2] in ["audio","video"] and f[3]=="calling":
        label = "non_genai"
        category = "calling"
        app = f[4]
        run_id = f[5]
        mode= f[2]
    else:
        label = "non_genai"
        category = f[2]
        app = f[3]
        run_id = f[4]
        mode= None



    rows.append({
        "file": file,
        "label": label,
        "category": category,
        "app": app,
        "mode": mode,
        "run_id": run_id
    })

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
meta = pd.DataFrame(rows).sort_values(["label", "app", "category", "mode", "run_id"])
print(meta)
# Out:
#                                                 file      label  category  \
# 0                 genai_chatgpt_audio_01_packets.csv      genai      None
# 1                 genai_chatgpt_audio_02_packets.csv      genai      None
# 2                  genai_chatgpt_text_01_packets.csv      genai      None
# 3                  genai_chatgpt_text_02_packets.csv      genai      None
# 4                  genai_chatgpt_text_03_packets.csv      genai      None
# 5                  genai_chatgpt_text_04_packets.csv      genai      None
# 6                  genai_chatgpt_text_05_packets.csv      genai      None
# 7                  genai_chatgpt_text_06_packets.csv      genai      None
# 8                 genai_chatgpt_video_01_packets.csv      genai      None
# 9                 genai_chatgpt_video_02_packets.csv      genai      None
# 10                genai_chatgpt_video_03_packets.csv      genai      None
# 11                genai_chatgpt_video_04_packets.csv      genai      None
# ...

# %%
meta_path = r"C:\Users\koush\Desktop\GenAi project folder\meta_index.csv"
meta.to_csv(meta_path, index=False)
meta.to_pickle(r"C:\Users\koush\Desktop\GenAi project folder\meta_index.pkl")
